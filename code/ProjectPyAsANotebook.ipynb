# %%
# %matplotlib inline

# %%
import os
import sys
#import time
#timestr = time.strftime("%Y%m%d-%H%M%S")
#os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
#os.environ["SPARK_HOME"] = "/content/spark-3.0.1-bin-hadoop3.2"
#os.environ["_JAVA_OPTIONS"]="-Xms512m -Xmx1024m  -Xss512m -XX:MaxPermSize=1024m"
os.environ["_JAVA_OPTIONS"]="-Xms512m -Xmx4096m  -Xss512m "
#os.environ['HADOOP_HOME'] = "/content/hadoop-3.3.0"
#sys.path.append("/content/hadoop-3.3.0/bin")




#import findspark
#findspark.init()
from pyspark.sql import SparkSession
from pyspark.sql import DataFrame
from pyspark.sql.functions import lit
from pyspark.sql.types import *
from functools import reduce

from pyspark.sql.functions import col

from pyspark.sql import SparkSession
from pyspark.sql import DataFrame
from pyspark.sql.functions import lit, col
from pyspark.sql.types import *
from functools import reduce
from pyspark.sql.functions import col
from petastorm.spark import SparkDatasetConverter, make_spark_converter
import numpy as np
import torch
import torchvision
from PIL import Image
from functools import partial 
from petastorm import TransformSpec
from torchvision import transforms
import errno
from datetime import datetime
import shutil
import random
import matplotlib.pyplot as charts
import time
from petastorm.spark import SparkDatasetConverter, make_spark_converter
from petastorm.spark_utils import dataset_as_rdd
from PIL import Image
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix

spark = SparkSession.builder.config("spark.driver.memory", "12g").config("spark.executor.memory", "12g").getOrCreate()
#spark = SparkSession.builder.config("spark.executor.memory", "6g").getOrCreate()
sc = spark.sparkContext

train_covid_df =  spark.read.format("image").option("dropInvalid", True).load("/mnt/data/X-RayImageDataSet/train/covid")
train_covid_df = train_covid_df.withColumn("class_name", lit(1))
train_covid_df = train_covid_df.withColumn("class_name", train_covid_df["class_name"].cast(LongType()))
train_covid_df = train_covid_df.withColumn("width", col("image").width)
train_covid_df = train_covid_df.withColumn("height", col("image").height)
train_covid_df = train_covid_df.withColumn("image", col("image").data)

train_nofindings_df =  spark.read.format("image").option("dropInvalid", True).load("/mnt/data/X-RayImageDataSet/train/nofindings")
train_nofindings_df = train_nofindings_df.withColumn("class_name", lit(0))
train_nofindings_df = train_nofindings_df.withColumn("class_name", train_nofindings_df["class_name"].cast(LongType()))
train_nofindings_df = train_nofindings_df.withColumn("width", col("image").width)
train_nofindings_df = train_nofindings_df.withColumn("height", col("image").height)
train_nofindings_df = train_nofindings_df.withColumn("image", col("image").data)

train_pneumonia_df =  spark.read.format("image").option("dropInvalid", True).load("/mnt/data/X-RayImageDataSet/train/pneumonia")
train_pneumonia_df = train_pneumonia_df.withColumn("class_name", lit(2))
train_pneumonia_df = train_pneumonia_df.withColumn("class_name", train_pneumonia_df["class_name"].cast(LongType()))
train_pneumonia_df = train_pneumonia_df.withColumn("width", col("image").width)
train_pneumonia_df = train_pneumonia_df.withColumn("height", col("image").height)
train_pneumonia_df = train_pneumonia_df.withColumn("image", col("image").data)

train_df = train_covid_df.union(train_nofindings_df).union(train_pneumonia_df)

test_covid_df =  spark.read.format("image").option("dropInvalid", True).load("/mnt/data/X-RayImageDataSet/test/covid")
test_covid_df = test_covid_df.withColumn("class_name", lit(1))
test_covid_df = test_covid_df.withColumn("class_name", test_covid_df["class_name"].cast(LongType()))
test_covid_df = test_covid_df.withColumn("width", col("image").width)
test_covid_df = test_covid_df.withColumn("height", col("image").height)
test_covid_df = test_covid_df.withColumn("image", col("image").data)

test_nofindings_df =  spark.read.format("image").option("dropInvalid", True).load("/mnt/data/X-RayImageDataSet/test/nofindings")
test_nofindings_df = test_nofindings_df.withColumn("class_name", lit(0))
test_nofindings_df = test_nofindings_df.withColumn("class_name", test_nofindings_df["class_name"].cast(LongType()))
test_nofindings_df = test_nofindings_df.withColumn("width", col("image").width)
test_nofindings_df = test_nofindings_df.withColumn("height", col("image").height)
test_nofindings_df = test_nofindings_df.withColumn("image", col("image").data)

test_pneumonia_df =  spark.read.format("image").option("dropInvalid", True).load("/mnt/data/X-RayImageDataSet/test/pneumonia")
test_pneumonia_df = test_pneumonia_df.withColumn("class_name", lit(2))
test_pneumonia_df = test_pneumonia_df.withColumn("class_name", test_pneumonia_df["class_name"].cast(LongType()))
test_pneumonia_df = test_pneumonia_df.withColumn("width", col("image").width)
test_pneumonia_df = test_pneumonia_df.withColumn("height", col("image").height)
test_pneumonia_df = test_pneumonia_df.withColumn("image", col("image").data)

test_df = test_covid_df.union(test_pneumonia_df).union(test_nofindings_df)

train_df = train_df.repartition(100)
test_df = test_df.repartition(100)

train_df.printSchema()
test_df.printSchema()

from pyspark.sql.functions import col

from petastorm.spark import SparkDatasetConverter, make_spark_converter

import io
import numpy as np
import torch
import torchvision
from PIL import Image
from functools import partial
from petastorm import TransformSpec
from torchvision import transforms

spark.conf.set(SparkDatasetConverter.PARENT_CACHE_DIR_URL_CONF, "file:///mnt/data/petacache")

converted_train_df = make_spark_converter(train_df)

converted_test_df = make_spark_converter(test_df)

print(f"train_covid: {len(converted_train_df)}")
print(f"test_covid: {len(converted_test_df)}")

#Function to show progress bar in the results
def ShowProgress(total, progress, label):
    barLength, status = 20, ""
    progress = float(progress) / float(total)
    if progress >= 1.:
        progress, status = 1, "\r\n"
    block = int(round(barLength * progress))
    text = "\r "+label+" [{}] {:.0f}% {}".format(
        "#" * block + "-" * (barLength - block), round(progress * 100, 0),
        status)

    sys.stdout.write(text)
    sys.stdout.flush()
    

import os
import shutil
import random
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as charts

from petastorm.spark import SparkDatasetConverter, make_spark_converter

from petastorm.spark_utils import dataset_as_rdd
from PIL import Image
from matplotlib import pyplot as plt

torch.manual_seed(0)

print('Using PyTorch version', torch.__version__)

#Transformation function for each of the row(image) in the dataset
def transform_row(is_train, pd_batch):
  #Load grascale(mode=L) image and convert to 3 channel RGB. This is required by all pretrained models.
  transformers = [transforms.Lambda(lambda x: Image.frombytes(mode="L", size=(x[0], x[1]), data=x[2]).convert('RGB'))]

  #Transformation on image
  if is_train:
    transformers.extend([
      transforms.Resize(256),
      transforms.CenterCrop(224),
      transforms.RandomHorizontalFlip(),
    ])
  else:
    transformers.extend([
      transforms.Resize(256),
      transforms.CenterCrop(224),
    ])

  transformers.extend([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]), #verify if this works for models other than resnet
  ])
  
  trans = transforms.Compose(transformers)

  pd_batch['image_meta'] = pd_batch.apply(lambda row: [row.width, row.height, row.image], axis=1)

  #Drop unwanted columns and keep only features and class_names columns
  pd_batch['features'] = pd_batch['image_meta'].map(lambda x: trans(x).numpy())#feature extraction
  pd_batch = pd_batch.drop(labels=['image'], axis=1)
  pd_batch = pd_batch.drop(labels=['width'], axis=1)
  pd_batch = pd_batch.drop(labels=['height'], axis=1)
  pd_batch = pd_batch.drop(labels=['image_meta'], axis=1)
  return pd_batch

#Trandformation function for the whole dataset
def get_transform_spec(is_train=True):
  return TransformSpec(partial(transform_row, is_train), 
                       edit_fields=[('features', np.float32, (3, 224, 224), False)], 
                       selected_fields=['features', 'class_name'])
    
CLASS_NAMES = ["nofindings","covid","pneumonia"]

NUM_CLASSES = 3
result_time_stamp = None

#Function to create results directory
def CreateResultDirectory(experiment_id):
    mydir = os.path.join(
        os.getcwd(), 
        "drive/MyDrive/covid19/results1",
        result_time_stamp,
        experiment_id)
    try:
        os.makedirs(mydir)
    except OSError as e:
        if e.errno != errno.EEXIST:
            raise
    return mydir

#Function to write results to the results directory
def WriteToFile(list, directory, filename):
  with open(os.path.join(directory, filename), 'w') as d:
        d.writelines(list)

#Function to display images. Not used
def show_images(images, labels, preds, BATCH_SIZE):
    plt.figure(figsize=(8, 4))
    for i, image in enumerate(images):
        plt.subplot(1, BATCH_SIZE, i + 1, xticks=[], yticks=[])
        image = image.numpy().transpose((1, 2, 0))
        mean = np.array([0.485, 0.456, 0.406])
        std = np.array([0.229, 0.224, 0.225])
        image = image * std + mean
        image = np.clip(image, 0., 1.)
        plt.imshow(image)
        col = 'green'
        if preds[i] != labels[i]:
            col = 'red'
            
        plt.xlabel(f'{CLASS_NAMES[int(labels[i].numpy())]}')
        plt.ylabel(f'{CLASS_NAMES[int(preds[i].numpy())]}', color=col)
    plt.tight_layout()
    plt.show()
    
#Function to plot accuracy and loss curves
def plot_learning_curves(train_losses, valid_losses, train_accuracies, valid_accuracies, MODEL_NAME, resultDirectory):
    graph, labels = plt.subplots(1, 2, figsize=(20, 10))
    labels[0].set_title('Loss Curves - ' + MODEL_NAME)
    labels[0].plot(train_losses, 'C0', label='Training Loss')
    labels[0].plot(valid_losses, 'C1', label='Validation Loss')
    labels[0].legend(loc="upper right")
    labels[0].set_xlabel("Epoch")
    labels[0].set_ylabel("Loss")

    labels[1].set_title('Accuracy Curves -  ' + MODEL_NAME)
    labels[1].plot(train_accuracies, 'C0', label='Training Accuracy')
    labels[1].plot(valid_accuracies, 'C1', label='Validation Accuracy')
    labels[1].legend(loc="upper left")
    labels[1].set_xlabel("Epoch")
    labels[1].set_ylabel("Accuracy")

    graph.savefig(resultDirectory + '/Learning_Curve-'+ MODEL_NAME +'.png')


def plot_confusion_matrix(results, MODEL_NAME, resultDirectory):
    y_true, y_pred = zip(*results)
    cm = confusion_matrix(y_true, y_pred)
    cm = cm.astype('float') / cm.astype('float').sum(axis=1)[:, np.newaxis]
    cm = np.around(cm, decimals=2)
    
    plt.figure()
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Normalized Confusion Matrix -  ' + MODEL_NAME)
    plt.colorbar()
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.xticks(np.arange(len(CLASS_NAMES)), CLASS_NAMES, rotation=45)
    plt.yticks(np.arange(len(CLASS_NAMES)), CLASS_NAMES)
    plt.tight_layout()

    threshold = cm.max() / 2.
    for i in range(cm.shape[0]):
            for j in range(cm.shape[1]):
                    color = 'black'
                    if cm[i,j] > threshold:
                            color = 'white'
                            
                    plt.text(j, i, cm[i, j], horizontalalignment='center', color=color)

    plt.savefig(resultDirectory + '/cm-'+MODEL_NAME+'.png')
#BATCH_SIZE = 6

#device = torch.device("cpu")
##resnet18 = torchvision.models.resnet18(pretrained=True)
#resnet18.fc = torch.nn.Linear(in_features=512, out_features=3)
#loss_fn = torch.nn.CrossEntropyLoss()
#optimizer = torch.optim.Adam(resnet18.parameters(), lr=3e-5)

#Function to set requires grad to False
def set_parameter_requires_grad(model):
  for param in model.parameters():
      param.requires_grad = False
        
#Function to initialie different models
def initialize_model(MODEL_NAME):
  model = None
  if MODEL_NAME == "resnet18":
    model = torchvision.models.resnet18(pretrained=True)
    set_parameter_requires_grad(model)
    num_features = model.fc.in_features
    model.fc = torch.nn.Linear(in_features=num_features, out_features=NUM_CLASSES)
  elif MODEL_NAME == "resnet34":
    model = torchvision.models.resnet34(pretrained=True)
    set_parameter_requires_grad(model)
    num_features = model.fc.in_features
    model.fc = torch.nn.Linear(in_features=num_features, out_features=NUM_CLASSES)
  elif MODEL_NAME == "resnet50":
    model = torchvision.models.resnet50(pretrained=True)
    set_parameter_requires_grad(model)
    num_features = model.fc.in_features
    model.fc = torch.nn.Linear(in_features=num_features, out_features=NUM_CLASSES)
  elif MODEL_NAME == "resnet101":
    model = torchvision.models.resnet101(pretrained=True)
    set_parameter_requires_grad(model)
    num_features = model.fc.in_features
    model.fc = torch.nn.Linear(in_features=num_features, out_features=NUM_CLASSES)
  elif MODEL_NAME == "resnet152":
    model = torchvision.models.resnet152(pretrained=True)
    set_parameter_requires_grad(model)
    num_features = model.fc.in_features
    model.fc = torch.nn.Linear(in_features=num_features, out_features=NUM_CLASSES)
  elif MODEL_NAME == "densenet":
    model = torchvision.models.densenet121(pretrained=True)
    set_parameter_requires_grad(model)
    num_features = model.classifier.in_features
    model.classifier = torch.nn.Linear(in_features=num_features, out_features=NUM_CLASSES)
  elif MODEL_NAME == "alexnet":
    model = torchvision.models.alexnet(pretrained=True)
    set_parameter_requires_grad(model)
    num_features = model.classifier[6].in_features
    model.classifier[6] = torch.nn.Linear(in_features=num_features, out_features=NUM_CLASSES)
  elif MODEL_NAME == "vgg":
    model = torchvision.models.vgg11_bn(pretrained=True)
    set_parameter_requires_grad(model)
    num_features = model.classifier[6].in_features
    model.classifier[6] = torch.nn.Linear(in_features=num_features, out_features=NUM_CLASSES)
  elif MODEL_NAME == "squeezenet":
    model = torchvision.models.squeezenet1_0(pretrained=True)
    set_parameter_requires_grad(model)
    model.classifier[1] = torch.nn.Conv2d(512, NUM_CLASSES, kernel_size=(1,1), stride=(1,1))
    model.num_classes = NUM_CLASSES
  else:
    print("Invalid model name, exiting...")
    exit()
  
  
  return model
        
def show_preds(images, labels):
    resnet18.eval()
    outputs = resnet18(images)
    _, preds = torch.max(outputs, 1)
    show_images(images, labels, preds)

#Function to train models
def train_model(model, loss_fn, optimizer, device, dataloader_iter, steps_per_phase, source_data_length, is_train=True):
    loss = 0.
    accuracy = 0.
    results = []
    progressText = "Training"

    if is_train == True:
      model.train()
    else:
      model.eval()
      progressText = "Validating"

    for step in range(steps_per_phase):
        ShowProgress(steps_per_phase, step+1, progressText)
        
        pb_batch = next(dataloader_iter)
        images, labels = pb_batch['features'].to(device), pb_batch['class_name'].to(device)
        optimizer.zero_grad()
        outputs = model(images)
        lossfn = loss_fn(outputs, labels)

        if is_train == True:
          lossfn.backward()
          optimizer.step()

        loss += lossfn.item()
        
        _, preds = torch.max(outputs, 1)
        accuracy += sum((preds.cpu() == labels.cpu()).numpy())

        if is_train == False:
          y_true = labels.detach().to('cpu').numpy().tolist()
          y_pred = preds.detach().to('cpu').numpy().tolist()
          results.extend(list(zip(y_true, y_pred)))

    loss /= steps_per_phase
    accuracy /= source_data_length
    return loss,accuracy,results

#Function to run model based on num of epocs
def Run_Model(MODEL_NAME, BATCH_SIZE, NUM_EPOCHS, LR, MOM, resultDirectory):
 
  device=None
  model = initialize_model(MODEL_NAME)
  bestModel = None
  best_val_acc = 0.0
  
  if torch.cuda.is_available():
    device = torch.device("cuda")
    model.cuda()
  else:
    device = torch.device("cpu")
    model.cpu()

  loss_fn = torch.nn.CrossEntropyLoss()
  optimizer = torch.optim.SGD(model.parameters(), lr=LR, momentum=MOM)
  scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

  train_losses, train_accuracies = [], []
  valid_losses, valid_accuracies = [], []
  log_result=[]


  with converted_train_df.make_torch_dataloader(transform_spec=get_transform_spec(is_train=True), batch_size=BATCH_SIZE) as train_dataloader, \
      converted_test_df.make_torch_dataloader(transform_spec=get_transform_spec(is_train=False), batch_size=BATCH_SIZE) as test_dataloader:

    train_dataloader_iter = iter(train_dataloader)
    steps_per_training = len(converted_train_df) // BATCH_SIZE

    test_dataloader_iter = iter(test_dataloader)
    steps_per_validation = len(converted_test_df) // BATCH_SIZE

    
    for e in range(NUM_EPOCHS):
        print("\n")
        print(f'Epoch: {e+1}/{NUM_EPOCHS}')
        
        train_loss, train_accuracy, results = train_model(model, loss_fn, optimizer, device, train_dataloader_iter, steps_per_training, len(converted_train_df), is_train=True)
        valid_loss, valid_accuracy, results = train_model(model, loss_fn, optimizer, device, test_dataloader_iter, steps_per_validation,  len(converted_test_df), is_train=False)

        if(scheduler!=None):
          scheduler.step()
      
        print(f'Training Loss: {train_loss:.4f}, Validation Loss: {valid_loss:.4f}', f'Training Accuracy: {train_accuracy:.4f}, Validation Accuracy: {valid_accuracy:.4f}')
        log_result.append(f'Epoch: {e+1}/{NUM_EPOCHS}' + f' - Training Loss: {train_loss:.4f}, Validation Loss: {valid_loss:.4f}' + f'Training Accuracy: {train_accuracy:.4f}, Validation Accuracy: {valid_accuracy:.4f}' + '\n')

        train_losses.append(train_loss)
        valid_losses.append(valid_loss)

        train_accuracies.append(train_accuracy)
        valid_accuracies.append(valid_accuracy)

        is_best = valid_accuracy > best_val_acc  
        if is_best:
          best_val_acc = valid_accuracy
          bestModel = model
          
    best_model_path = resultDirectory + '/best-'+ str(best_val_acc) + "-" +MODEL_NAME+'-model.pth'
    torch.save(bestModel, best_model_path)
    print("\n")
    print("Generating plots and confusion matrix:")
    best_model = torch.load(best_model_path)
    test_loss, test_accuracy, test_results = train_model(best_model, loss_fn, optimizer, device, test_dataloader_iter, steps_per_validation,  len(converted_test_df), is_train=False)
    plot_confusion_matrix(test_results, MODEL_NAME, resultDirectory)

    WriteToFile(log_result, resultDirectory, "Result_Log_"+MODEL_NAME+".txt")
    plot_learning_curves(train_losses, valid_losses, train_accuracies, valid_accuracies, MODEL_NAME, resultDirectory)

def Run_Experiment(experiment_id, models_to_evaluate, BATCH_SIZE, NUM_EPOCHS, LR, MOM):
  resultDirectory = CreateResultDirectory("Experiment " + str(experiment_id))
  print("Results folder: " + resultDirectory)

  WriteToFile(["Batch Size: " + str(BATCH_SIZE) + "\n","Num Epochs: " + str(NUM_EPOCHS) + "\n", "Learning Rate: " + str(LR) + "\n", "Momentum: " + str(MOM) + "\n"], resultDirectory, "Result_Metadata.txt")

  for model_nm in models_to_evaluate:
    print("Running Experiment "+ str(experiment_id) +" for model: " + model_nm)
    Run_Model(model_nm, BATCH_SIZE, NUM_EPOCHS, LR, MOM, resultDirectory) 
    

def test(epochs, test_dataloader_iter, steps_per_validation):
    print('='*20)
    print(f'Starting epoch {epochs}')
    print('='*20)
    val_loss = 0.
    accuracy = 0.

    resnet18.eval() # set model to eval phase

    for test_step in range(steps_per_validation):
        if test_step % 20 == 0:
            percent = test_step/steps_per_validation*100
            print(f'PercentComplete: {percent:.2f}')

        pb_batch = next(test_dataloader_iter)
        images, labels = pb_batch['features'].to(device), pb_batch['class_name'].to(device)
        optimizer.zero_grad()
        outputs = resnet18(images)
        loss = loss_fn(outputs, labels)
        val_loss += loss.item()

        _, preds = torch.max(outputs, 1)
        accuracy += sum((preds == labels).numpy())

    val_loss /= (test_step + 1)
    accuracy = accuracy/len(converted_test_df)
    print(f'Validation Loss: {val_loss:.4f}, Validation Accuracy: {accuracy:.4f}')

    return val_loss,accuracy


result_time_stamp = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')


models_to_evaluate = ["resnet18","densenet", "vgg", "squeezenet","resnet34","resnet18","resnet50","resnet101","resnet152","alexnet"]
Run_Experiment(1,models_to_evaluate, BATCH_SIZE=32, NUM_EPOCHS=30, LR=0.001, MOM=0.9)

#models_to_evaluate = ["resnet18","densenet", "vgg", "squeezenet","resnet34","resnet18","resnet50","resnet101","alexnet"]
#Run_Experiment(2,models_to_evaluate, BATCH_SIZE=32, NUM_EPOCHS=20, LR=0.001, MOM=0.9)

#models_to_evaluate = ["resnet18","densenet", "vgg", "squeezenet"]
#Run_Experiment(2,models_to_evaluate, BATCH_SIZE=32, NUM_EPOCHS=20, LR=0.0001, MOM=0.9)

#models_to_evaluate = ["resnet18","densenet", "vgg", "squeezenet"]
#Run_Experiment(3,models_to_evaluate, BATCH_SIZE=32, NUM_EPOCHS=20, LR=0.00001, MOM=0.9)
# Out:
# Converting floating-point columns to float32
# root
#  |-- image: binary (nullable = true)
#  |-- class_name: long (nullable = false)
#  |-- width: integer (nullable = true)
#  |-- height: integer (nullable = true)
#
# root
#  |-- image: binary (nullable = true)
#  |-- class_name: long (nullable = false)
#  |-- width: integer (nullable = true)
#  |-- height: integer (nullable = true)
# Converting floating-point columns to float32
# The median size 13732843 B (< 50 MB) of the parquet files is too small. Total size: 1615469429 B. Increase the median file size by calling df.repartition(n) or df.coalesce(n), which might help improve the performance. Parquet files: file:///mnt/data/petacache/20201205051742-appid-local-1607145223625-4365c480-0b60-4c33-99a2-289ce3ff3d19/part-00028-977e84f3-9f14-4288-8802-aab390781994-c000.parquet, ...
# train_covid: 2937
# test_covid: 751
# Using PyTorch version 1.7.0
# Results folder: /mnt/host/drive/MyDrive/covid19/results1/2020-12-05_05-18-17/Experiment 1
# Running Experiment 1 for model: resnet18
#
#
# Epoch: 1/30
#  Training [--------------------] 1%
# /opt/conda/lib/python3.8/site-packages/petastorm/arrow_reader_worker.py:53: FutureWarning: Calling .data on ChunkedArray is provided for compatibility after Column was removed, simply drop this attribute
#   column_as_pandas = column.data.chunks[0].to_pandas()
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.6560, Validation Loss: 0.5197 Training Accuracy: 0.7072, Validation Accuracy: 0.7617
#
#
# Epoch: 2/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4766, Validation Loss: 0.4855 Training Accuracy: 0.7923, Validation Accuracy: 0.7763
#
#
# Epoch: 3/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4559, Validation Loss: 0.4513 Training Accuracy: 0.8008, Validation Accuracy: 0.7870
#
#
# Epoch: 4/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4362, Validation Loss: 0.4484 Training Accuracy: 0.8069, Validation Accuracy: 0.7870
#
#
# Epoch: 5/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4263, Validation Loss: 0.4636 Training Accuracy: 0.8080, Validation Accuracy: 0.7643
#
#
# Epoch: 6/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4095, Validation Loss: 0.4581 Training Accuracy: 0.8151, Validation Accuracy: 0.7816
#
#
# Epoch: 7/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4087, Validation Loss: 0.4230 Training Accuracy: 0.8151, Validation Accuracy: 0.7896
#
#
# Epoch: 8/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3972, Validation Loss: 0.4387 Training Accuracy: 0.8161, Validation Accuracy: 0.7883
#
#
# Epoch: 9/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3935, Validation Loss: 0.4393 Training Accuracy: 0.8308, Validation Accuracy: 0.7856
#
#
# Epoch: 10/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3926, Validation Loss: 0.4292 Training Accuracy: 0.8172, Validation Accuracy: 0.7883
#
#
# Epoch: 11/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3796, Validation Loss: 0.4393 Training Accuracy: 0.8345, Validation Accuracy: 0.7790
#
#
# Epoch: 12/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3836, Validation Loss: 0.4281 Training Accuracy: 0.8233, Validation Accuracy: 0.8029
#
#
# Epoch: 13/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3934, Validation Loss: 0.4202 Training Accuracy: 0.8117, Validation Accuracy: 0.7963
#
#
# Epoch: 14/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3852, Validation Loss: 0.4142 Training Accuracy: 0.8270, Validation Accuracy: 0.7923
#
#
# Epoch: 15/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3776, Validation Loss: 0.4679 Training Accuracy: 0.8315, Validation Accuracy: 0.7763
#
#
# Epoch: 16/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3860, Validation Loss: 0.4316 Training Accuracy: 0.8178, Validation Accuracy: 0.7909
#
#
# Epoch: 17/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3846, Validation Loss: 0.4105 Training Accuracy: 0.8277, Validation Accuracy: 0.7976
#
#
# Epoch: 18/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3732, Validation Loss: 0.4264 Training Accuracy: 0.8349, Validation Accuracy: 0.7843
#
#
# Epoch: 19/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3782, Validation Loss: 0.4417 Training Accuracy: 0.8291, Validation Accuracy: 0.7803
#
#
# Epoch: 20/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3831, Validation Loss: 0.4198 Training Accuracy: 0.8219, Validation Accuracy: 0.8056
#
#
# Epoch: 21/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3849, Validation Loss: 0.4283 Training Accuracy: 0.8250, Validation Accuracy: 0.7816
#
#
# Epoch: 22/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3605, Validation Loss: 0.4310 Training Accuracy: 0.8407, Validation Accuracy: 0.7883
#
#
# Epoch: 23/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3867, Validation Loss: 0.4242 Training Accuracy: 0.8243, Validation Accuracy: 0.7803
#
#
# Epoch: 24/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3825, Validation Loss: 0.4264 Training Accuracy: 0.8206, Validation Accuracy: 0.7989
#
#
# Epoch: 25/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3738, Validation Loss: 0.4791 Training Accuracy: 0.8359, Validation Accuracy: 0.7670
#
#
# Epoch: 26/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3715, Validation Loss: 0.3904 Training Accuracy: 0.8349, Validation Accuracy: 0.8043
#
#
# Epoch: 27/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3806, Validation Loss: 0.4533 Training Accuracy: 0.8209, Validation Accuracy: 0.7816
#
#
# Epoch: 28/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3704, Validation Loss: 0.4408 Training Accuracy: 0.8342, Validation Accuracy: 0.7989
#
#
# Epoch: 29/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3861, Validation Loss: 0.4063 Training Accuracy: 0.8253, Validation Accuracy: 0.7949
#
#
# Epoch: 30/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3794, Validation Loss: 0.4480 Training Accuracy: 0.8270, Validation Accuracy: 0.7776
#
#
# Generating plots and confusion matrix:
#  Validating [####################] 100%
# Running Experiment 1 for model: densenet
#
#
# Epoch: 1/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.6669, Validation Loss: 0.5245 Training Accuracy: 0.7028, Validation Accuracy: 0.7710
#
#
# Epoch: 2/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4881, Validation Loss: 0.4684 Training Accuracy: 0.7957, Validation Accuracy: 0.8003
#
#
# Epoch: 3/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4491, Validation Loss: 0.4683 Training Accuracy: 0.8107, Validation Accuracy: 0.7803
#
#
# Epoch: 4/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4324, Validation Loss: 0.4665 Training Accuracy: 0.8199, Validation Accuracy: 0.7843
#
#
# Epoch: 5/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4218, Validation Loss: 0.4506 Training Accuracy: 0.8189, Validation Accuracy: 0.7949
#
#
# Epoch: 6/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4107, Validation Loss: 0.4492 Training Accuracy: 0.8233, Validation Accuracy: 0.7989
#
#
# Epoch: 7/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3958, Validation Loss: 0.4544 Training Accuracy: 0.8219, Validation Accuracy: 0.7923
#
#
# Epoch: 8/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4041, Validation Loss: 0.4312 Training Accuracy: 0.8253, Validation Accuracy: 0.8069
#
#
# Epoch: 9/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3817, Validation Loss: 0.4360 Training Accuracy: 0.8342, Validation Accuracy: 0.8043
#
#
# Epoch: 10/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3922, Validation Loss: 0.4594 Training Accuracy: 0.8301, Validation Accuracy: 0.7856
#
#
# Epoch: 11/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3784, Validation Loss: 0.4457 Training Accuracy: 0.8301, Validation Accuracy: 0.7909
#
#
# Epoch: 12/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3703, Validation Loss: 0.4459 Training Accuracy: 0.8342, Validation Accuracy: 0.8109
#
#
# Epoch: 13/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3773, Validation Loss: 0.4477 Training Accuracy: 0.8396, Validation Accuracy: 0.7909
#
#
# Epoch: 14/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3637, Validation Loss: 0.4189 Training Accuracy: 0.8369, Validation Accuracy: 0.8056
#
#
# Epoch: 15/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3704, Validation Loss: 0.4771 Training Accuracy: 0.8379, Validation Accuracy: 0.7723
#
#
# Epoch: 16/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3630, Validation Loss: 0.4402 Training Accuracy: 0.8468, Validation Accuracy: 0.8029
#
#
# Epoch: 17/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3671, Validation Loss: 0.4265 Training Accuracy: 0.8447, Validation Accuracy: 0.8083
#
#
# Epoch: 18/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3709, Validation Loss: 0.4147 Training Accuracy: 0.8369, Validation Accuracy: 0.8043
#
#
# Epoch: 19/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3694, Validation Loss: 0.4591 Training Accuracy: 0.8355, Validation Accuracy: 0.7936
#
#
# Epoch: 20/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3803, Validation Loss: 0.4444 Training Accuracy: 0.8355, Validation Accuracy: 0.7976
#
#
# Epoch: 21/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3688, Validation Loss: 0.4291 Training Accuracy: 0.8430, Validation Accuracy: 0.8069
#
#
# Epoch: 22/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3702, Validation Loss: 0.4035 Training Accuracy: 0.8345, Validation Accuracy: 0.8083
#
#
# Epoch: 23/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3635, Validation Loss: 0.4436 Training Accuracy: 0.8458, Validation Accuracy: 0.7989
#
#
# Epoch: 24/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3562, Validation Loss: 0.4512 Training Accuracy: 0.8447, Validation Accuracy: 0.7989
#
#
# Epoch: 25/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3779, Validation Loss: 0.4691 Training Accuracy: 0.8376, Validation Accuracy: 0.7776
#
#
# Epoch: 26/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3731, Validation Loss: 0.4226 Training Accuracy: 0.8277, Validation Accuracy: 0.8003
#
#
# Epoch: 27/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3690, Validation Loss: 0.4460 Training Accuracy: 0.8430, Validation Accuracy: 0.7989
#
#
# Epoch: 28/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3697, Validation Loss: 0.4248 Training Accuracy: 0.8379, Validation Accuracy: 0.8016
#
#
# Epoch: 29/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3642, Validation Loss: 0.4308 Training Accuracy: 0.8372, Validation Accuracy: 0.8043
#
#
# Epoch: 30/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3641, Validation Loss: 0.4265 Training Accuracy: 0.8379, Validation Accuracy: 0.8056
#
#
# Generating plots and confusion matrix:
#  Validating [####################] 100%
# Running Experiment 1 for model: vgg
#
#
# Epoch: 1/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.5903, Validation Loss: 0.4878 Training Accuracy: 0.7375, Validation Accuracy: 0.7696
#
#
# Epoch: 2/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4711, Validation Loss: 0.4456 Training Accuracy: 0.7906, Validation Accuracy: 0.7816
#
#
# Epoch: 3/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4413, Validation Loss: 0.4463 Training Accuracy: 0.7991, Validation Accuracy: 0.7803
#
#
# Epoch: 4/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4330, Validation Loss: 0.4201 Training Accuracy: 0.8001, Validation Accuracy: 0.7896
#
#
# Epoch: 5/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4354, Validation Loss: 0.4165 Training Accuracy: 0.8114, Validation Accuracy: 0.7963
#
#
# Epoch: 6/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4220, Validation Loss: 0.4286 Training Accuracy: 0.8165, Validation Accuracy: 0.7830
#
#
# Epoch: 7/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4063, Validation Loss: 0.4162 Training Accuracy: 0.8219, Validation Accuracy: 0.7870
#
#
# Epoch: 8/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4109, Validation Loss: 0.4147 Training Accuracy: 0.8199, Validation Accuracy: 0.7963
#
#
# Epoch: 9/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4162, Validation Loss: 0.4199 Training Accuracy: 0.8090, Validation Accuracy: 0.7830
#
#
# Epoch: 10/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3945, Validation Loss: 0.3988 Training Accuracy: 0.8236, Validation Accuracy: 0.7976
#
#
# Epoch: 11/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4004, Validation Loss: 0.4185 Training Accuracy: 0.8236, Validation Accuracy: 0.7776
#
#
# Epoch: 12/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3900, Validation Loss: 0.4065 Training Accuracy: 0.8199, Validation Accuracy: 0.7909
#
#
# Epoch: 13/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3951, Validation Loss: 0.4005 Training Accuracy: 0.8202, Validation Accuracy: 0.7963
#
#
# Epoch: 14/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3984, Validation Loss: 0.4059 Training Accuracy: 0.8141, Validation Accuracy: 0.7923
#
#
# Epoch: 15/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3941, Validation Loss: 0.4089 Training Accuracy: 0.8209, Validation Accuracy: 0.7843
#
#
# Epoch: 16/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4046, Validation Loss: 0.4016 Training Accuracy: 0.8270, Validation Accuracy: 0.7883
#
#
# Epoch: 17/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3802, Validation Loss: 0.4225 Training Accuracy: 0.8352, Validation Accuracy: 0.7843
#
#
# Epoch: 18/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3935, Validation Loss: 0.4052 Training Accuracy: 0.8182, Validation Accuracy: 0.7776
#
#
# Epoch: 19/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3911, Validation Loss: 0.3959 Training Accuracy: 0.8199, Validation Accuracy: 0.7949
#
#
# Epoch: 20/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3860, Validation Loss: 0.4016 Training Accuracy: 0.8298, Validation Accuracy: 0.7936
#
#
# Epoch: 21/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3906, Validation Loss: 0.4165 Training Accuracy: 0.8304, Validation Accuracy: 0.7803
#
#
# Epoch: 22/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3949, Validation Loss: 0.3880 Training Accuracy: 0.8236, Validation Accuracy: 0.8016
#
#
# Epoch: 23/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3823, Validation Loss: 0.3927 Training Accuracy: 0.8284, Validation Accuracy: 0.7949
#
#
# Epoch: 24/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4003, Validation Loss: 0.4212 Training Accuracy: 0.8158, Validation Accuracy: 0.7750
#
#
# Epoch: 25/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3833, Validation Loss: 0.4138 Training Accuracy: 0.8332, Validation Accuracy: 0.7936
#
#
# Epoch: 26/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3899, Validation Loss: 0.4076 Training Accuracy: 0.8199, Validation Accuracy: 0.7896
#
#
# Epoch: 27/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4002, Validation Loss: 0.4122 Training Accuracy: 0.8151, Validation Accuracy: 0.7856
#
#
# Epoch: 28/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3897, Validation Loss: 0.3992 Training Accuracy: 0.8253, Validation Accuracy: 0.7896
#
#
# Epoch: 29/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3774, Validation Loss: 0.4048 Training Accuracy: 0.8355, Validation Accuracy: 0.7856
#
#
# Epoch: 30/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3914, Validation Loss: 0.3944 Training Accuracy: 0.8243, Validation Accuracy: 0.7896
#
#
# Generating plots and confusion matrix:
#  Validating [####################] 100%
# Running Experiment 1 for model: squeezenet
#
#
# Epoch: 1/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.6088, Validation Loss: 0.5001 Training Accuracy: 0.7215, Validation Accuracy: 0.7696
#
#
# Epoch: 2/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4428, Validation Loss: 0.4442 Training Accuracy: 0.7998, Validation Accuracy: 0.7870
#
#
# Epoch: 3/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4150, Validation Loss: 0.4353 Training Accuracy: 0.8076, Validation Accuracy: 0.7923
#
#
# Epoch: 4/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4057, Validation Loss: 0.4494 Training Accuracy: 0.8158, Validation Accuracy: 0.7856
#
#
# Epoch: 5/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3980, Validation Loss: 0.3838 Training Accuracy: 0.8127, Validation Accuracy: 0.8083
#
#
# Epoch: 6/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3958, Validation Loss: 0.4568 Training Accuracy: 0.8172, Validation Accuracy: 0.7896
#
#
# Epoch: 7/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3817, Validation Loss: 0.3966 Training Accuracy: 0.8212, Validation Accuracy: 0.8083
#
#
# Epoch: 8/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3777, Validation Loss: 0.4028 Training Accuracy: 0.8202, Validation Accuracy: 0.7989
#
#
# Epoch: 9/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3698, Validation Loss: 0.4086 Training Accuracy: 0.8308, Validation Accuracy: 0.7936
#
#
# Epoch: 10/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3713, Validation Loss: 0.3855 Training Accuracy: 0.8315, Validation Accuracy: 0.8069
#
#
# Epoch: 11/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3657, Validation Loss: 0.4188 Training Accuracy: 0.8291, Validation Accuracy: 0.7963
#
#
# Epoch: 12/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3525, Validation Loss: 0.3973 Training Accuracy: 0.8349, Validation Accuracy: 0.8056
#
#
# Epoch: 13/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3553, Validation Loss: 0.4049 Training Accuracy: 0.8386, Validation Accuracy: 0.7976
#
#
# Epoch: 14/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3559, Validation Loss: 0.3839 Training Accuracy: 0.8362, Validation Accuracy: 0.8136
#
#
# Epoch: 15/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3553, Validation Loss: 0.4004 Training Accuracy: 0.8362, Validation Accuracy: 0.8029
#
#
# Epoch: 16/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3506, Validation Loss: 0.4011 Training Accuracy: 0.8304, Validation Accuracy: 0.8056
#
#
# Epoch: 17/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3531, Validation Loss: 0.4131 Training Accuracy: 0.8366, Validation Accuracy: 0.7923
#
#
# Epoch: 18/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3553, Validation Loss: 0.3874 Training Accuracy: 0.8359, Validation Accuracy: 0.8096
#
#
# Epoch: 19/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3514, Validation Loss: 0.3737 Training Accuracy: 0.8349, Validation Accuracy: 0.8216
#
#
# Epoch: 20/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3590, Validation Loss: 0.4188 Training Accuracy: 0.8321, Validation Accuracy: 0.7776
#
#
# Epoch: 21/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3517, Validation Loss: 0.4146 Training Accuracy: 0.8369, Validation Accuracy: 0.8016
#
#
# Epoch: 22/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3451, Validation Loss: 0.3817 Training Accuracy: 0.8447, Validation Accuracy: 0.8083
#
#
# Epoch: 23/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3523, Validation Loss: 0.4030 Training Accuracy: 0.8328, Validation Accuracy: 0.7963
#
#
# Epoch: 24/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3423, Validation Loss: 0.3959 Training Accuracy: 0.8383, Validation Accuracy: 0.8069
#
#
# Epoch: 25/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3598, Validation Loss: 0.3744 Training Accuracy: 0.8345, Validation Accuracy: 0.8083
#
#
# Epoch: 26/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3387, Validation Loss: 0.4138 Training Accuracy: 0.8424, Validation Accuracy: 0.7936
#
#
# Epoch: 27/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3505, Validation Loss: 0.3958 Training Accuracy: 0.8349, Validation Accuracy: 0.7976
#
#
# Epoch: 28/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3497, Validation Loss: 0.4037 Training Accuracy: 0.8349, Validation Accuracy: 0.8029
#
#
# Epoch: 29/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3400, Validation Loss: 0.3880 Training Accuracy: 0.8441, Validation Accuracy: 0.8136
#
#
# Epoch: 30/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3564, Validation Loss: 0.4006 Training Accuracy: 0.8294, Validation Accuracy: 0.7909
#
#
# Generating plots and confusion matrix:
#  Validating [####################] 100%
# Running Experiment 1 for model: resnet34
#
#
# Epoch: 1/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.6148, Validation Loss: 0.4894 Training Accuracy: 0.7181, Validation Accuracy: 0.7630
#
#
# Epoch: 2/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4683, Validation Loss: 0.4716 Training Accuracy: 0.7916, Validation Accuracy: 0.7643
#
#
# Epoch: 3/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4365, Validation Loss: 0.4345 Training Accuracy: 0.7981, Validation Accuracy: 0.7803
#
#
# Epoch: 4/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4311, Validation Loss: 0.4172 Training Accuracy: 0.7978, Validation Accuracy: 0.7856
#
#
# Epoch: 5/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4183, Validation Loss: 0.4549 Training Accuracy: 0.8097, Validation Accuracy: 0.7723
#
#
# Epoch: 6/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4172, Validation Loss: 0.4214 Training Accuracy: 0.8066, Validation Accuracy: 0.7949
#
#
# Epoch: 7/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4089, Validation Loss: 0.4075 Training Accuracy: 0.8117, Validation Accuracy: 0.7949
#
#
# Epoch: 8/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4084, Validation Loss: 0.4046 Training Accuracy: 0.8141, Validation Accuracy: 0.7963
#
#
# Epoch: 9/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4026, Validation Loss: 0.4352 Training Accuracy: 0.8206, Validation Accuracy: 0.7763
#
#
# Epoch: 10/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3945, Validation Loss: 0.3957 Training Accuracy: 0.8175, Validation Accuracy: 0.8083
#
#
# Epoch: 11/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3888, Validation Loss: 0.3923 Training Accuracy: 0.8243, Validation Accuracy: 0.8083
#
#
# Epoch: 12/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3789, Validation Loss: 0.4030 Training Accuracy: 0.8308, Validation Accuracy: 0.8016
#
#
# Epoch: 13/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3746, Validation Loss: 0.3950 Training Accuracy: 0.8315, Validation Accuracy: 0.7949
#
#
# Epoch: 14/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3850, Validation Loss: 0.4176 Training Accuracy: 0.8264, Validation Accuracy: 0.7723
#
#
# Epoch: 15/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3762, Validation Loss: 0.3736 Training Accuracy: 0.8335, Validation Accuracy: 0.8229
#
#
# Epoch: 16/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3719, Validation Loss: 0.3998 Training Accuracy: 0.8352, Validation Accuracy: 0.7870
#
#
# Epoch: 17/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3682, Validation Loss: 0.3976 Training Accuracy: 0.8318, Validation Accuracy: 0.7909
#
#
# Epoch: 18/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3811, Validation Loss: 0.4147 Training Accuracy: 0.8257, Validation Accuracy: 0.7949
#
#
# Epoch: 19/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3806, Validation Loss: 0.3837 Training Accuracy: 0.8335, Validation Accuracy: 0.8003
#
#
# Epoch: 20/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3827, Validation Loss: 0.4142 Training Accuracy: 0.8192, Validation Accuracy: 0.7896
#
#
# Epoch: 21/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3766, Validation Loss: 0.3862 Training Accuracy: 0.8264, Validation Accuracy: 0.7976
#
#
# Epoch: 22/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3694, Validation Loss: 0.4281 Training Accuracy: 0.8318, Validation Accuracy: 0.7843
#
#
# Epoch: 23/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3776, Validation Loss: 0.3989 Training Accuracy: 0.8287, Validation Accuracy: 0.7923
#
#
# Epoch: 24/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3764, Validation Loss: 0.3769 Training Accuracy: 0.8267, Validation Accuracy: 0.8189
#
#
# Epoch: 25/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3734, Validation Loss: 0.4023 Training Accuracy: 0.8311, Validation Accuracy: 0.7923
#
#
# Epoch: 26/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3780, Validation Loss: 0.4026 Training Accuracy: 0.8250, Validation Accuracy: 0.7896
#
#
# Epoch: 27/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3743, Validation Loss: 0.4094 Training Accuracy: 0.8260, Validation Accuracy: 0.8056
#
#
# Epoch: 28/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3728, Validation Loss: 0.3699 Training Accuracy: 0.8311, Validation Accuracy: 0.8003
#
#
# Epoch: 29/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3747, Validation Loss: 0.4147 Training Accuracy: 0.8281, Validation Accuracy: 0.7830
#
#
# Epoch: 30/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3708, Validation Loss: 0.3900 Training Accuracy: 0.8304, Validation Accuracy: 0.8003
#
#
# Generating plots and confusion matrix:
#  Validating [####################] 100%
# Running Experiment 1 for model: resnet18
#
#
# Epoch: 1/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.6219, Validation Loss: 0.5342 Training Accuracy: 0.7324, Validation Accuracy: 0.7403
#
#
# Epoch: 2/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4859, Validation Loss: 0.4765 Training Accuracy: 0.7841, Validation Accuracy: 0.7683
#
#
# Epoch: 3/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4491, Validation Loss: 0.4591 Training Accuracy: 0.8018, Validation Accuracy: 0.7870
#
#
# Epoch: 4/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4287, Validation Loss: 0.4652 Training Accuracy: 0.8052, Validation Accuracy: 0.7723
#
#
# Epoch: 5/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4158, Validation Loss: 0.4504 Training Accuracy: 0.8073, Validation Accuracy: 0.7776
#
#
# Epoch: 6/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4070, Validation Loss: 0.4399 Training Accuracy: 0.8127, Validation Accuracy: 0.7830
#
#
# Epoch: 7/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4110, Validation Loss: 0.4274 Training Accuracy: 0.8117, Validation Accuracy: 0.7843
#
#
# Epoch: 8/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3956, Validation Loss: 0.4350 Training Accuracy: 0.8151, Validation Accuracy: 0.7949
#
#
# Epoch: 9/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3920, Validation Loss: 0.4240 Training Accuracy: 0.8216, Validation Accuracy: 0.8003
#
#
# Epoch: 10/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4017, Validation Loss: 0.4380 Training Accuracy: 0.8127, Validation Accuracy: 0.7736
#
#
# Epoch: 11/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3837, Validation Loss: 0.4481 Training Accuracy: 0.8298, Validation Accuracy: 0.7763
#
#
# Epoch: 12/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3876, Validation Loss: 0.4399 Training Accuracy: 0.8301, Validation Accuracy: 0.7816
#
#
# Epoch: 13/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3757, Validation Loss: 0.4136 Training Accuracy: 0.8315, Validation Accuracy: 0.8003
#
#
# Epoch: 14/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3811, Validation Loss: 0.4214 Training Accuracy: 0.8315, Validation Accuracy: 0.7856
#
#
# Epoch: 15/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3832, Validation Loss: 0.4522 Training Accuracy: 0.8240, Validation Accuracy: 0.7670
#
#
# Epoch: 16/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3761, Validation Loss: 0.4174 Training Accuracy: 0.8304, Validation Accuracy: 0.7790
#
#
# Epoch: 17/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3918, Validation Loss: 0.4804 Training Accuracy: 0.8206, Validation Accuracy: 0.7590
#
#
# Epoch: 18/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3784, Validation Loss: 0.3987 Training Accuracy: 0.8270, Validation Accuracy: 0.8029
#
#
# Epoch: 19/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3792, Validation Loss: 0.4346 Training Accuracy: 0.8253, Validation Accuracy: 0.7909
#
#
# Epoch: 20/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3743, Validation Loss: 0.4255 Training Accuracy: 0.8315, Validation Accuracy: 0.7723
#
#
# Epoch: 21/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3877, Validation Loss: 0.4338 Training Accuracy: 0.8247, Validation Accuracy: 0.7803
#
#
# Epoch: 22/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3700, Validation Loss: 0.4301 Training Accuracy: 0.8315, Validation Accuracy: 0.7843
#
#
# Epoch: 23/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3767, Validation Loss: 0.4559 Training Accuracy: 0.8284, Validation Accuracy: 0.7577
#
#
# Epoch: 24/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3747, Validation Loss: 0.4189 Training Accuracy: 0.8291, Validation Accuracy: 0.7949
#
#
# Epoch: 25/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3770, Validation Loss: 0.4246 Training Accuracy: 0.8294, Validation Accuracy: 0.7923
#
#
# Epoch: 26/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3722, Validation Loss: 0.4217 Training Accuracy: 0.8315, Validation Accuracy: 0.7776
#
#
# Epoch: 27/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3815, Validation Loss: 0.4780 Training Accuracy: 0.8291, Validation Accuracy: 0.7470
#
#
# Epoch: 28/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3895, Validation Loss: 0.4242 Training Accuracy: 0.8250, Validation Accuracy: 0.7870
#
#
# Epoch: 29/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3826, Validation Loss: 0.4242 Training Accuracy: 0.8229, Validation Accuracy: 0.7830
#
#
# Epoch: 30/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3757, Validation Loss: 0.4284 Training Accuracy: 0.8247, Validation Accuracy: 0.7790
#
#
# Generating plots and confusion matrix:
#  Validating [####################] 100%
# Running Experiment 1 for model: resnet50
#
#
# Epoch: 1/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.6350, Validation Loss: 0.5241 Training Accuracy: 0.7222, Validation Accuracy: 0.7617
#
#
# Epoch: 2/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4726, Validation Loss: 0.4900 Training Accuracy: 0.7916, Validation Accuracy: 0.7683
#
#
# Epoch: 3/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4407, Validation Loss: 0.4945 Training Accuracy: 0.8110, Validation Accuracy: 0.7670
#
#
# Epoch: 4/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4265, Validation Loss: 0.4696 Training Accuracy: 0.8110, Validation Accuracy: 0.7843
#
#
# Epoch: 5/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4245, Validation Loss: 0.4580 Training Accuracy: 0.8015, Validation Accuracy: 0.7830
#
#
# Epoch: 6/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4015, Validation Loss: 0.4253 Training Accuracy: 0.8199, Validation Accuracy: 0.7989
#
#
# Epoch: 7/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4040, Validation Loss: 0.4618 Training Accuracy: 0.8250, Validation Accuracy: 0.7816
#
#
# Epoch: 8/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3985, Validation Loss: 0.4642 Training Accuracy: 0.8127, Validation Accuracy: 0.7856
#
#
# Epoch: 9/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3949, Validation Loss: 0.4270 Training Accuracy: 0.8216, Validation Accuracy: 0.7936
#
#
# Epoch: 10/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3969, Validation Loss: 0.4590 Training Accuracy: 0.8168, Validation Accuracy: 0.7870
#
#
# Epoch: 11/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3761, Validation Loss: 0.4450 Training Accuracy: 0.8328, Validation Accuracy: 0.7989
#
#
# Epoch: 12/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3678, Validation Loss: 0.4328 Training Accuracy: 0.8338, Validation Accuracy: 0.7989
#
#
# Epoch: 13/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3779, Validation Loss: 0.4539 Training Accuracy: 0.8267, Validation Accuracy: 0.7896
#
#
# Epoch: 14/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3873, Validation Loss: 0.4166 Training Accuracy: 0.8260, Validation Accuracy: 0.7976
#
#
# Epoch: 15/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3690, Validation Loss: 0.4367 Training Accuracy: 0.8304, Validation Accuracy: 0.7936
#
#
# Epoch: 16/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3834, Validation Loss: 0.4470 Training Accuracy: 0.8270, Validation Accuracy: 0.7896
#
#
# Epoch: 17/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3798, Validation Loss: 0.4427 Training Accuracy: 0.8308, Validation Accuracy: 0.7989
#
#
# Epoch: 18/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3713, Validation Loss: 0.4358 Training Accuracy: 0.8366, Validation Accuracy: 0.7936
#
#
# Epoch: 19/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3791, Validation Loss: 0.4238 Training Accuracy: 0.8304, Validation Accuracy: 0.8109
#
#
# Epoch: 20/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3695, Validation Loss: 0.4450 Training Accuracy: 0.8308, Validation Accuracy: 0.7896
#
#
# Epoch: 21/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3846, Validation Loss: 0.4346 Training Accuracy: 0.8277, Validation Accuracy: 0.7923
#
#
# Epoch: 22/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3598, Validation Loss: 0.4305 Training Accuracy: 0.8417, Validation Accuracy: 0.7949
#
#
# Epoch: 23/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3668, Validation Loss: 0.4171 Training Accuracy: 0.8304, Validation Accuracy: 0.7883
#
#
# Epoch: 24/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3812, Validation Loss: 0.4513 Training Accuracy: 0.8260, Validation Accuracy: 0.7963
#
#
# Epoch: 25/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3643, Validation Loss: 0.4429 Training Accuracy: 0.8393, Validation Accuracy: 0.7909
#
#
# Epoch: 26/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3785, Validation Loss: 0.4207 Training Accuracy: 0.8260, Validation Accuracy: 0.7989
#
#
# Epoch: 27/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3796, Validation Loss: 0.4602 Training Accuracy: 0.8304, Validation Accuracy: 0.7923
#
#
# Epoch: 28/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3639, Validation Loss: 0.4394 Training Accuracy: 0.8311, Validation Accuracy: 0.7989
#
#
# Epoch: 29/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3734, Validation Loss: 0.4455 Training Accuracy: 0.8233, Validation Accuracy: 0.7856
#
#
# Epoch: 30/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3698, Validation Loss: 0.4846 Training Accuracy: 0.8386, Validation Accuracy: 0.7790
#
#
# Generating plots and confusion matrix:
#  Validating [####################] 100%
# Running Experiment 1 for model: resnet101
#
#
# Epoch: 1/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.6474, Validation Loss: 0.5395 Training Accuracy: 0.7096, Validation Accuracy: 0.7577
#
#
# Epoch: 2/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4677, Validation Loss: 0.5115 Training Accuracy: 0.7920, Validation Accuracy: 0.7457
#
#
# Epoch: 3/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4425, Validation Loss: 0.4972 Training Accuracy: 0.8069, Validation Accuracy: 0.7617
#
#
# Epoch: 4/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4208, Validation Loss: 0.4999 Training Accuracy: 0.8131, Validation Accuracy: 0.7696
#
#
# Epoch: 5/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4132, Validation Loss: 0.4600 Training Accuracy: 0.8144, Validation Accuracy: 0.7816
#
#
# Epoch: 6/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4104, Validation Loss: 0.4820 Training Accuracy: 0.8168, Validation Accuracy: 0.7643
#
#
# Epoch: 7/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4002, Validation Loss: 0.4491 Training Accuracy: 0.8253, Validation Accuracy: 0.7923
#
#
# Epoch: 8/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3885, Validation Loss: 0.4512 Training Accuracy: 0.8332, Validation Accuracy: 0.7776
#
#
# Epoch: 9/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3839, Validation Loss: 0.4316 Training Accuracy: 0.8257, Validation Accuracy: 0.8083
#
#
# Epoch: 10/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3746, Validation Loss: 0.4648 Training Accuracy: 0.8291, Validation Accuracy: 0.7603
#
#
# Epoch: 11/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3743, Validation Loss: 0.4331 Training Accuracy: 0.8328, Validation Accuracy: 0.7870
#
#
# Epoch: 12/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3673, Validation Loss: 0.4558 Training Accuracy: 0.8311, Validation Accuracy: 0.7843
#
#
# Epoch: 13/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3642, Validation Loss: 0.4465 Training Accuracy: 0.8376, Validation Accuracy: 0.7856
#
#
# Epoch: 14/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3711, Validation Loss: 0.4728 Training Accuracy: 0.8325, Validation Accuracy: 0.7643
#
#
# Epoch: 15/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3628, Validation Loss: 0.4552 Training Accuracy: 0.8362, Validation Accuracy: 0.7790
#
#
# Epoch: 16/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3674, Validation Loss: 0.4579 Training Accuracy: 0.8410, Validation Accuracy: 0.7790
#
#
# Epoch: 17/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3682, Validation Loss: 0.4274 Training Accuracy: 0.8372, Validation Accuracy: 0.8016
#
#
# Epoch: 18/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3726, Validation Loss: 0.4496 Training Accuracy: 0.8308, Validation Accuracy: 0.7790
#
#
# Epoch: 19/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3609, Validation Loss: 0.4834 Training Accuracy: 0.8407, Validation Accuracy: 0.7856
#
#
# Epoch: 20/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3685, Validation Loss: 0.4567 Training Accuracy: 0.8274, Validation Accuracy: 0.7763
#
#
# Epoch: 21/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3619, Validation Loss: 0.4139 Training Accuracy: 0.8396, Validation Accuracy: 0.8056
#
#
# Epoch: 22/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3696, Validation Loss: 0.4505 Training Accuracy: 0.8352, Validation Accuracy: 0.7803
#
#
# Epoch: 23/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3567, Validation Loss: 0.4331 Training Accuracy: 0.8366, Validation Accuracy: 0.7883
#
#
# Epoch: 24/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3650, Validation Loss: 0.4960 Training Accuracy: 0.8318, Validation Accuracy: 0.7710
#
#
# Epoch: 25/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3715, Validation Loss: 0.4287 Training Accuracy: 0.8355, Validation Accuracy: 0.8043
#
#
# Epoch: 26/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3653, Validation Loss: 0.4573 Training Accuracy: 0.8338, Validation Accuracy: 0.7830
#
#
# Epoch: 27/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3549, Validation Loss: 0.4613 Training Accuracy: 0.8420, Validation Accuracy: 0.7630
#
#
# Epoch: 28/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3666, Validation Loss: 0.4398 Training Accuracy: 0.8318, Validation Accuracy: 0.7963
#
#
# Epoch: 29/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3687, Validation Loss: 0.4361 Training Accuracy: 0.8379, Validation Accuracy: 0.7803
#
#
# Epoch: 30/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3645, Validation Loss: 0.4684 Training Accuracy: 0.8393, Validation Accuracy: 0.7736
#
#
# Generating plots and confusion matrix:
#  Validating [####################] 100%
# Running Experiment 1 for model: resnet152
# Downloading: "https://download.pytorch.org/models/resnet152-b121ed2d.pth" to /root/.cache/torch/hub/checkpoints/resnet152-b121ed2d.pth
# HBox(children=(FloatProgress(value=0.0, max=241530880.0), HTML(value='')))
# Epoch: 1/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.6377, Validation Loss: 0.5896 Training Accuracy: 0.7174, Validation Accuracy: 0.7124
#
#
# Epoch: 2/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4685, Validation Loss: 0.4669 Training Accuracy: 0.7947, Validation Accuracy: 0.7830
#
#
# Epoch: 3/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4412, Validation Loss: 0.4464 Training Accuracy: 0.8073, Validation Accuracy: 0.7870
#
#
# Epoch: 4/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4189, Validation Loss: 0.4301 Training Accuracy: 0.8110, Validation Accuracy: 0.8029
#
#
# Epoch: 5/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4134, Validation Loss: 0.4297 Training Accuracy: 0.8131, Validation Accuracy: 0.7949
#
#
# Epoch: 6/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4004, Validation Loss: 0.4047 Training Accuracy: 0.8138, Validation Accuracy: 0.8083
#
#
# Epoch: 7/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3892, Validation Loss: 0.4125 Training Accuracy: 0.8257, Validation Accuracy: 0.8083
#
#
# Epoch: 8/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3899, Validation Loss: 0.4082 Training Accuracy: 0.8274, Validation Accuracy: 0.8043
#
#
# Epoch: 9/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3888, Validation Loss: 0.4313 Training Accuracy: 0.8192, Validation Accuracy: 0.7989
#
#
# Epoch: 10/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3749, Validation Loss: 0.3960 Training Accuracy: 0.8383, Validation Accuracy: 0.8109
#
#
# Epoch: 11/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3684, Validation Loss: 0.3968 Training Accuracy: 0.8349, Validation Accuracy: 0.8096
#
#
# Epoch: 12/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3691, Validation Loss: 0.3899 Training Accuracy: 0.8359, Validation Accuracy: 0.7989
#
#
# Epoch: 13/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3694, Validation Loss: 0.4325 Training Accuracy: 0.8321, Validation Accuracy: 0.7949
#
#
# Epoch: 14/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3596, Validation Loss: 0.3965 Training Accuracy: 0.8366, Validation Accuracy: 0.8162
#
#
# Epoch: 15/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3586, Validation Loss: 0.4292 Training Accuracy: 0.8369, Validation Accuracy: 0.7963
#
#
# Epoch: 16/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3657, Validation Loss: 0.3876 Training Accuracy: 0.8359, Validation Accuracy: 0.8123
#
#
# Epoch: 17/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3584, Validation Loss: 0.4107 Training Accuracy: 0.8359, Validation Accuracy: 0.8003
#
#
# Epoch: 18/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3785, Validation Loss: 0.3916 Training Accuracy: 0.8206, Validation Accuracy: 0.8162
#
#
# Epoch: 19/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3632, Validation Loss: 0.4092 Training Accuracy: 0.8400, Validation Accuracy: 0.8016
#
#
# Epoch: 20/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3655, Validation Loss: 0.4003 Training Accuracy: 0.8274, Validation Accuracy: 0.8149
#
#
# Epoch: 21/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3603, Validation Loss: 0.4167 Training Accuracy: 0.8407, Validation Accuracy: 0.7936
#
#
# Epoch: 22/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3732, Validation Loss: 0.3758 Training Accuracy: 0.8304, Validation Accuracy: 0.8096
#
#
# Epoch: 23/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3558, Validation Loss: 0.4121 Training Accuracy: 0.8362, Validation Accuracy: 0.7963
#
#
# Epoch: 24/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3618, Validation Loss: 0.3881 Training Accuracy: 0.8342, Validation Accuracy: 0.8083
#
#
# Epoch: 25/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3670, Validation Loss: 0.4091 Training Accuracy: 0.8311, Validation Accuracy: 0.7909
#
#
# Epoch: 26/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3564, Validation Loss: 0.3914 Training Accuracy: 0.8410, Validation Accuracy: 0.8123
#
#
# Epoch: 27/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3697, Validation Loss: 0.3996 Training Accuracy: 0.8349, Validation Accuracy: 0.7963
#
#
# Epoch: 28/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3491, Validation Loss: 0.3926 Training Accuracy: 0.8444, Validation Accuracy: 0.8123
#
#
# Epoch: 29/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3670, Validation Loss: 0.3961 Training Accuracy: 0.8294, Validation Accuracy: 0.8043
#
#
# Epoch: 30/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3708, Validation Loss: 0.3919 Training Accuracy: 0.8311, Validation Accuracy: 0.8056
#
#
# Generating plots and confusion matrix:
#  Validating [####################] 100%
# Running Experiment 1 for model: alexnet
#
#
# Epoch: 1/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.6755, Validation Loss: 0.4661 Training Accuracy: 0.7211, Validation Accuracy: 0.7870
#
#
# Epoch: 2/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.5020, Validation Loss: 0.5054 Training Accuracy: 0.7818, Validation Accuracy: 0.7763
#
#
# Epoch: 3/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.5127, Validation Loss: 0.5380 Training Accuracy: 0.7797, Validation Accuracy: 0.7617
#
#
# Epoch: 4/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.5440, Validation Loss: 0.4205 Training Accuracy: 0.7794, Validation Accuracy: 0.8136
#
#
# Epoch: 5/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4581, Validation Loss: 0.6516 Training Accuracy: 0.8012, Validation Accuracy: 0.7337
#
#
# Epoch: 6/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4798, Validation Loss: 0.4278 Training Accuracy: 0.7923, Validation Accuracy: 0.8016
#
#
# Epoch: 7/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4356, Validation Loss: 0.3878 Training Accuracy: 0.8063, Validation Accuracy: 0.8109
#
#
# Epoch: 8/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4089, Validation Loss: 0.4147 Training Accuracy: 0.8148, Validation Accuracy: 0.8043
#
#
# Epoch: 9/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4595, Validation Loss: 0.4348 Training Accuracy: 0.7961, Validation Accuracy: 0.8003
#
#
# Epoch: 10/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.4337, Validation Loss: 0.3801 Training Accuracy: 0.8121, Validation Accuracy: 0.8229
#
#
# Epoch: 11/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3902, Validation Loss: 0.3687 Training Accuracy: 0.8223, Validation Accuracy: 0.8096
#
#
# Epoch: 12/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3704, Validation Loss: 0.3865 Training Accuracy: 0.8308, Validation Accuracy: 0.8096
#
#
# Epoch: 13/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3663, Validation Loss: 0.4034 Training Accuracy: 0.8311, Validation Accuracy: 0.7976
#
#
# Epoch: 14/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3704, Validation Loss: 0.3742 Training Accuracy: 0.8349, Validation Accuracy: 0.8136
#
#
# Epoch: 15/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3760, Validation Loss: 0.3484 Training Accuracy: 0.8291, Validation Accuracy: 0.8229
#
#
# Epoch: 16/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3667, Validation Loss: 0.3846 Training Accuracy: 0.8264, Validation Accuracy: 0.8016
#
#
# Epoch: 17/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3741, Validation Loss: 0.3281 Training Accuracy: 0.8315, Validation Accuracy: 0.8322
#
#
# Epoch: 18/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3540, Validation Loss: 0.4078 Training Accuracy: 0.8338, Validation Accuracy: 0.7976
#
#
# Epoch: 19/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3546, Validation Loss: 0.3763 Training Accuracy: 0.8325, Validation Accuracy: 0.8256
#
#
# Epoch: 20/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3591, Validation Loss: 0.3570 Training Accuracy: 0.8308, Validation Accuracy: 0.8162
#
#
# Epoch: 21/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3578, Validation Loss: 0.3815 Training Accuracy: 0.8250, Validation Accuracy: 0.8123
#
#
# Epoch: 22/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3632, Validation Loss: 0.3510 Training Accuracy: 0.8287, Validation Accuracy: 0.8202
#
#
# Epoch: 23/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3638, Validation Loss: 0.3752 Training Accuracy: 0.8352, Validation Accuracy: 0.8136
#
#
# Epoch: 24/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3640, Validation Loss: 0.3630 Training Accuracy: 0.8250, Validation Accuracy: 0.8202
#
#
# Epoch: 25/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3508, Validation Loss: 0.3758 Training Accuracy: 0.8376, Validation Accuracy: 0.8176
#
#
# Epoch: 26/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3495, Validation Loss: 0.3547 Training Accuracy: 0.8321, Validation Accuracy: 0.8216
#
#
# Epoch: 27/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3681, Validation Loss: 0.3562 Training Accuracy: 0.8328, Validation Accuracy: 0.8149
#
#
# Epoch: 28/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3457, Validation Loss: 0.4226 Training Accuracy: 0.8379, Validation Accuracy: 0.8069
#
#
# Epoch: 29/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3653, Validation Loss: 0.3380 Training Accuracy: 0.8311, Validation Accuracy: 0.8242
#
#
# Epoch: 30/30
#  Training [####################] 100%
#  Validating [####################] 100%
# Training Loss: 0.3636, Validation Loss: 0.3795 Training Accuracy: 0.8294, Validation Accuracy: 0.8149
#
#
# Generating plots and confusion matrix:
#  Validating [####################] 100%
